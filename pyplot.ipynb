# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y, "g")
plt.show()

# %%
plt.plot(x,y,'gx')
plt.show()

# %%
plt.plot(x,y,'gs-')
plt.show()

# %%
plt.plot(x,y,'gD:')
plt.show()

# %%
plt.hist(x,)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()
